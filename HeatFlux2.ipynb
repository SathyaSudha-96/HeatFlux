# %% [markdown]
# <a href="https://colab.research.google.com/github/SathyaSudha-96/HeatFlux/blob/main/HeatFlux2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importing the libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from tensorflow.keras import backend as K

# %%
df = pd.read_csv('/content/drive/MyDrive/HeatFlux/Input.csv')
df.head()
# Out:
#    Position           0       0.005  ...       4.985        4.99       4.995
# 0      0.00  518.158288  518.159996  ...  509.650242  509.637845  509.625453
# 1      0.95  518.541005  518.543565  ...  509.984789  509.972578  509.960373
# 2      1.90  518.912601  518.915998  ...  510.311772  510.299750  510.287737
# 3      2.85  519.273289  519.277522  ...  510.632420  510.620594  510.608778
# 4      3.80  519.624387  519.629473  ...  510.948544  510.936918  510.925304
#
# [5 rows x 1001 columns]

# %%
df2 = pd.read_csv('/content/drive/MyDrive/HeatFlux/Output.csv')
df2.head()
# Out:
#    position            0        0.005  ...        4.985         4.99        4.995
# 0      0.00  15473.49742  13359.62959  ...  552796.8358  553282.2116  553766.8434
# 1      0.95  13742.31730  11956.20790  ...  580290.9585  580781.1511  581270.5408
# 2      1.90  14652.22677  12778.93893  ...  614440.9408  614941.0634  615440.3344
# 3      2.85  17062.94345  14877.04259  ...  654839.2302  655354.0509  655867.9809
# 4      3.80  20296.58970  17686.13226  ...  700935.7864  701469.7523  702002.7984
#
# [5 rows x 1001 columns]

# %%
import seaborn as sns; sns.set_theme()
uniform_data = df[['0.005']]
ax = sns.heatmap(uniform_data)

# %%
uniform_data = df2[['0.005']]
ax = sns.heatmap(uniform_data)

# %%
input = df.transpose()
input.columns = input.iloc[0]
input = input.drop(['Position'])
d = input.index
#input['Time'] = d
#X = input.transpose()
#X.head()
input.head()
# Out:
# Position      0.00        0.95    ...      239.40      240.35
# 0         518.158288  518.541005  ...  512.294751  510.166490
# 0.005     518.159996  518.543565  ...  510.824425  508.544539
# 0.01      518.161673  518.546091  ...  509.353417  506.922018
# 0.015     518.163317  518.548584  ...  507.881727  505.298929
# 0.02      518.164928  518.551042  ...  506.409353  503.675272
#
# [5 rows x 254 columns]

# %%
output = df2.transpose()
output = output.drop(['position'])
#output['Time'] = d
output.columns = input.columns 
#Y = output.transpose()
#Y.head()
output.head()
# Out:
# Position       0.00         0.95    ...       239.40       240.35
# 0         15473.49742  13742.31730  ...  194667.3428  284817.8570
# 0.005     13359.62959  11956.20790  ...  255853.7385  361111.8717
# 0.01      12649.48533  11673.55457  ...  322067.2693  448031.2257
# 0.015     12654.56257  12441.40119  ...  394998.4559  548603.9304
# 0.02      13943.51452  14648.21900  ...  478480.5814  651767.5300
#
# [5 rows x 254 columns]

# %%
print(input.shape)
print(output.shape)
# Out:
# (1000, 254)
# (1000, 254)

# %%
input.info()
output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 4.995
# Columns: 254 entries, 0.0 to 240.35
# dtypes: float64(254)
# memory usage: 1.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 4.995
# Columns: 254 entries, 0.0 to 240.35
# dtypes: float64(254)
# memory usage: 1.9+ MB

# %%
input.tail()
# Out:
# Position      0.00        0.95    ...      239.40      240.35
# 4.975     509.675052  510.009232  ...  117.619226  118.453865
# 4.98      509.662645  509.997007  ...  117.640046  118.474248
# 4.985     509.650242  509.984789  ...  117.660874  118.494648
# 4.99      509.637845  509.972578  ...  117.681715  118.515067
# 4.995     509.625453  509.960373  ...  117.702570  118.535509
#
# [5 rows x 254 columns]

# %%
#X = df.iloc[:,0:254]
#y = df2.iloc[:,0:254]
X = np.array(input)
Y = np.array(output)

# %%
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled_input = scaler.fit_transform(X)
print(scaled_input)
# Out:
# [[0.99505566 0.98885235 0.98026069 ... 1.         1.         1.        ]
#  [0.99525486 0.98914734 0.98064669 ... 0.99674265 0.99635184 0.99595422]
#  [0.99545034 0.9894385  0.98102874 ... 0.99348336 0.99270199 0.99190701]
#  ...
#  [0.00289077 0.0028138  0.00273163 ... 0.019074   0.02083812 0.0230166 ]
#  [0.00144507 0.00140652 0.00136535 ... 0.0191265  0.02088983 0.02306753]
#  [0.         0.         0.         ... 0.01917902 0.02094158 0.02311852]]

# %%
scaled_input.shape
# Out:
# (1000, 254)

# %%
# transform data
scaled_output = scaler.fit_transform(Y)
print(scaled_output)
# Out:
# [[5.21885326e-03 3.63197626e-03 3.43177668e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.31236644e-03 4.96233893e-04 3.24426335e-04 ... 7.76247597e-04
#   9.84448477e-04 1.22935473e-03]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.62441259e-03
#   2.04978022e-03 2.62991964e-03]
#  ...
#  [9.98207399e-01 9.98280219e-01 9.98342238e-01 ... 9.93153408e-01
#   9.92392121e-01 9.91467638e-01]
#  [9.99104387e-01 9.99140814e-01 9.99171825e-01 ... 9.93130391e-01
#   9.92368996e-01 9.91444331e-01]
#  [1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 9.93107194e-01
#   9.92345606e-01 9.91420721e-01]]

# %%
print(scaled_input.shape)
print(scaled_output.shape)
# Out:
# (1000, 254)
# (1000, 254)

# %%
# Let's say we want to split the data in 80:10:10 for train:valid:test dataset
train_size=0.8

# In the first step we will split the data in training and remaining dataset
X_train, X_rem, y_train, y_rem = train_test_split(scaled_input,scaled_output, train_size=0.8)

# Now since we want the valid and test size to be equal (10% each of overall data). 
# we have to define valid_size=0.5 (that is 50% of remaining data)
test_size = 0.5
X_valid, X_test, y_valid, y_test = train_test_split(X_rem,y_rem, test_size=0.5)

print(X_train.shape), print(y_train.shape)
print(X_valid.shape), print(y_valid.shape)
print(X_test.shape), print(y_test.shape)
# Out:
# (800, 254)
# (800, 254)
# (100, 254)
# (100, 254)
# (100, 254)
# (100, 254)
# (None, None)

# %%
# get the model
def get_model(n_inputs, n_outputs):
	model = Sequential()
	model.add(Dense(20, input_dim=n_inputs, kernel_initializer='he_uniform', activation='relu'))
  model.add(Dense(20,))
	model.add(Dense(n_outputs))
	model.compile(loss='mae', optimizer='adam')
	return model

# %%
# evaluate a model using repeated k-fold cross-validation
def evaluate_model(X, Y):
	results = list()
	n_inputs, n_outputs = X.shape[1], Y.shape[1]
	# define evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# enumerate folds
	for train_ix, test_ix in cv.split(X):
		# prepare data
		X_train, X_test = X[train_ix], X[test_ix]
		y_train, y_test = Y[train_ix], Y[test_ix]
		# define model
		model = get_model(n_inputs, n_outputs)
		# fit model
		model.fit(X_train, y_train, verbose=0, epochs=100)
		# evaluate model on test set
		mae = model.evaluate(X_test, y_test, verbose=0)
		# store result
		#print('>%.3f' % mae)
		results.append(mae)
	return results

# %%
from numpy import mean
from numpy import std
# evaluate model
results = evaluate_model(X_train, y_train)
# summarize performance
print('MAE: %.3f (%.3f)' % (mean(results), std(results)))
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fe713b440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4fe703cc20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# MAE: 0.015 (0.005)

# %%
n_inputs, n_outputs = X.shape[1], Y.shape[1]
# get model
model = get_model(n_inputs, n_outputs)
# fit the model on all data
#model.fit(X_train, y_train, verbose=0, epochs=100)
model.fit(scaled_input,scaled_output, verbose=0, epochs=100)
# make a prediction for new data
prediction= model.predict(scaled_input)
#print('Predicted: %s' % prediction[0])

# %%
model.summary()
# Out:
# Model: "sequential_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_62 (Dense)             (None, 20)                5100
# _________________________________________________________________
# dense_63 (Dense)             (None, 254)               5334
# =================================================================
# Total params: 10,434
# Trainable params: 10,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import mean_absolute_error
error = mean_absolute_error(scaled_output, prediction)
error
# Out:
# 0.012873458118922104

# %%
x_ax = range(len(X_rem))
plt.scatter(x_ax, y_rem[:,0],  s=6, label="y1-test")
plt.plot(x_ax, prediction[:,0], label="y1-pred")
plt.legend()
plt.show()

# %%
act_x = pd.DataFrame(X_rem,columns = input.columns,index = input.index[0:200])
act_x = act_x.transpose()
act_y = pd.DataFrame(y_rem,columns = input.columns,index = input.index[0:200])
act_y = act_y.transpose()
pred_y = pd.DataFrame(prediction,columns = input.columns,index = input.index[0:200])
pred_y = pred_y.transpose()

# %%
act_X = pd.DataFrame(scaled_input,columns = input.columns,index = input.index)
#act_X = act_X.transpose()
act_Y = pd.DataFrame(scaled_output,columns = input.columns,index = input.index)
#act_Y = act_Y.transpose()
pred_Y = pd.DataFrame(prediction,columns = input.columns,index = input.index)
#pred_Y = pred_Y.transpose()

# %%
act_X.shape
# Out:
# (1000, 254)

# %%
act_X.to_csv('/content/drive/MyDrive/HeatFlux/actual_temperature.csv',)
act_Y.to_csv('/content/drive/MyDrive/HeatFlux/actual_HeatFlux.csv',)
pred_Y.to_csv('/content/drive/MyDrive/HeatFlux/predicted_HeatFlux.csv',)

# %%
actual_YData = act_y[['0.04']]
ax = sns.heatmap(actual_YData)

# %%
predicted_YData = pred_y[['0.04']]
ax = sns.heatmap(predicted_YData)

# %%
act_X[240.35]
# Out:
# 0        1.000000
# 0.005    0.995954
# 0.01     0.991907
# 0.015    0.987858
# 0.02     0.983808
#            ...
# 4.975    0.022915
# 4.98     0.022966
# 4.985    0.023017
# 4.99     0.023068
# 4.995    0.023119
# Name: 240.35, Length: 1000, dtype: float64

# %%
# plotting the line 1 points 
plt.plot(act_x[['0.4']], act_y[['0.4']], label = "Actual")
# plotting the line 2 points 
plt.plot(act_x[['0.4']], pred_y[['0.4']], label = "Predicted")
plt.xlabel('Temperature')
# Set the y axis label of the current axis.
plt.ylabel('HeatFlux')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
# create a Keras function to get i-th layer
get_layer_output = K.function(inputs=model.layers[0].input, outputs=model.layers[1].output)
# extract output
layer_output = get_layer_output(X_train)

# %%
print(layer_output)
# Out:
# [[0.606386   0.5971332  0.5922581  ... 1.0220472  1.02185    1.0203891 ]
#  [0.4020614  0.39754993 0.39292753 ... 0.6216439  0.6631548  0.70608896]
#  [0.36270645 0.36006895 0.35626265 ... 0.5274413  0.57866055 0.6319473 ]
#  ...
#  [0.38144574 0.37791592 0.37372103 ... 0.57229686 0.6188934  0.66725063]
#  [0.5887525  0.5782563  0.5720829  ... 1.0168736  1.0173945  1.0166659 ]
#  [0.5291019  0.51854116 0.51128423 ... 0.9257363  0.93590784 0.94542325]]

# %%
act_X.head()
# Out:
# Position    0.00      0.95      1.90    ...    238.45    239.40    240.35
# 0         0.995056  0.988852  0.980261  ...  1.000000  1.000000  1.000000
# 0.005     0.995255  0.989147  0.980647  ...  0.996743  0.996352  0.995954
# 0.01      0.995450  0.989438  0.981029  ...  0.993483  0.992702  0.991907
# 0.015     0.995642  0.989726  0.981407  ...  0.990222  0.989050  0.987858
# 0.02      0.995830  0.990009  0.981781  ...  0.986959  0.985397  0.983808
#
# [5 rows x 254 columns]

# %%
# plotting the line 1 points 
plt.plot(act_X[19.00], act_Y[19.00], label = "Actual")
# plotting the line 2 points 
plt.plot(act_X[19.00], pred_Y[19.00], label = "Predicted")
plt.xlabel('Temperature')
# Set the y axis label of the current axis.
plt.ylabel('HeatFlux')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
# plotting the line 1 points 
plt.plot(act_X[230.85], act_Y[230.85], label = "Actual")
# plotting the line 2 points 
plt.plot(act_X[230.85], pred_Y[230.85], label = "Predicted")
plt.xlabel('Temperature')
# Set the y axis label of the current axis.
plt.ylabel('HeatFlux')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()

# %%
# plotting the line 1 points 
plt.plot(act_X[220.4], act_Y[220.4], label = "Actual")
# plotting the line 2 points 
plt.plot(act_X[220.4], pred_Y[220.4], label = "Predicted")
plt.xlabel('Temperature')
# Set the y axis label of the current axis.
plt.ylabel('HeatFlux')
# Set a title of the current axes.
plt.title('Two or more lines on same plot with suitable legends ')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()
